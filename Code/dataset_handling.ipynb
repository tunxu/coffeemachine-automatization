# %% [markdown]
# # Check for validity of Data

# %%
import os
import json

with open("../data/audio_label.json", "r") as file:
    dict = json.load(file)

dict.keys()
# Out:
# dict_keys(['ok_leo.wav', 'klein_yuna.wav', 'ok_nah.wav', 'gross_yuna.wav', 'klein.wav', 'gross_leise.wav', 'klein_fern.wav', 'klein_nah.wav', 'gross.wav', 'kaffee_fern.wav', 'ok_vietanh.wav', 'kaffee_yuna.wav', 'fernando_leo.wav', 'klein_leise.wav', 'kaffee_leise.wav', 'ok_fern.wav', 'kaffee.wav', 'gross_nah.wav', 'ok_yuna.wav', 'fernando_yuna.wav', 'kaffee_hasan.wav', 'klein_vietanh.wav', 'fernando_leise.wav', 'gross_leo.wav', 'klein_leo.wav', 'klein_hasan.wav', 'kaffee_leo.wav', 'fernando_fern.wav', 'fernando_hasan.wav', 'gross_hasan.wav', 'kaffee-vietanh.wav', 'fernando.wav', 'kaffee_nah.wav', 'fernando_nah.wav', 'ok_leise.wav', 'ok.wav', 'fernando_vietanh.wav', 'gross_fern.wav', 'ok_hasan.wav', 'gross_vietanh.wav'])
